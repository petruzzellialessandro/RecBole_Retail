# %%
from recbole.quick_start import run_recbole, load_data_and_model
from recbole.utils import get_trainer

# %% [markdown]
# # GRU4Rec

# %%
dict_results = run_recbole(model="GRU4Rec", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')
# Out:
# 27 Jan 19:13    INFO  ['c:\\Users\\petru\\Documents\\python_envs\\recbole\\lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\petru\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-6200gzmHGRQQnyp7.json']
# 27 Jan 19:13    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path =
#  ..\RECEIPT_LINES
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 1
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'AveragePopularity', 'TailPercentage', 'ItemCoverage']
# topk = [1, 10, 50, 100]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 1024
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = Key_receipt
# ITEM_ID_FIELD = Key_product
# RATING_FIELD = rating
# TIME_FIELD = TS_T_RECEIPT
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product'], 'item': ['D_PRODUCT', 'K_PRODUCT_TYPE', 'Key_product', 'hierachy']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 7
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# hidden_size = 128
# num_layers = 1
# dropout_prob = 0.3
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# reproducibility' = True
# D_PRODUCT_FIELD = D_PRODUCT
# device = cuda
# K_PRODUCT_TYPE_FIELD = K_PRODUCT_TYPE
# Key_receipt_FIELD = Key_receipt
# LINE_NUM_FIELD = LINE_NUM
# QUANTITY_FIELD = QUANTITY
# Q_AMOUNT_FIELD = Q_AMOUNT
# Q_DISCOUNT_AMOUNT_FIELD = Q_DISCOUNT_AMOUNT
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\recbole\data\dataset\dataset.py:1217: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   split_point = np.cumsum(feat[field].agg(len))[:-1]
# 27 Jan 19:13    INFO  RECEIPT_LINES
# The number of users: 1103980
# Average actions of users: 1.6437604338488323
# The number of items: 62763
# Average actions of items: 28.91362607947484
# The number of inters: 1814677
# The sparsity of the dataset: 99.99738100641315%
# Remain Fields: ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product', 'D_PRODUCT', 'K_PRODUCT_TYPE']
# 27 Jan 19:13    INFO  [Training]: train_batch_size = [4096] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 27 Jan 19:13    INFO  [Evaluation]: eval_batch_size = [1024] eval_args: [{'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}]
# 27 Jan 19:13    INFO  GRU4Rec(
#   (item_embedding): Embedding(62763, 64, padding_idx=0)
#   (emb_dropout): Dropout(p=0.3, inplace=False)
#   (gru_layers): GRU(64, 128, bias=False, batch_first=True)
#   (dense): Linear(in_features=128, out_features=64, bias=True)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 4098816
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\torch\nn\modules\rnn.py:1102: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at ..\aten\src\ATen\native\cudnn\RNN.cpp:982.)
#   result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
# 27 Jan 19:13    INFO  FLOPs: 580224.0
# Train     0:   0%|                                                          | 0/120 [00:00<?, ?it/s]:   0%|                                  | 0/120 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/120 [00:00<00:31,  3.82it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/120 [00:00<00:31,  3.82it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/120 [00:00<00:31,  3.82it/s, GPU RAM: 3.50 G/8.00 G]:   2%|▋                         | 3/120 [00:00<00:16,  7.31it/s, GPU RAM: 3.50 G/8.00 G]:   2%|▋                         | 3/120 [00:00<00:16,  7.31it/s, GPU RAM: 3.50 G/8.00 G]:   2%|▋                         | 3/120 [00:00<00:16,  7.31it/s, GPU RAM: 3.50 G/8.00 G]:   4%|█                         | 5/120 [00:00<00:12,  8.88it/s, GPU RAM: 3.50 G/8.00 G]:   4%|█                         | 5/120 [00:00<00:12,  8.88it/s, GPU RAM: 3.50 G/8.00 G]:   4%|█                         | 5/120 [00:00<00:12,  8.88it/s, GPU RAM: 3.50 G/8.00 G]:   6%|█▌                        | 7/120 [00:00<00:11,  9.74it/s, GPU RAM: 3.50 G/8.00 G]:   6%|█▌                        | 7/120 [00:00<00:11,  9.74it/s, GPU RAM: 3.50 G/8.00 G]:   6%|█▌                        | 7/120 [00:00<00:11,  9.74it/s, GPU RAM: 3.50 G/8.00 G]:   8%|█▉                        | 9/120 [00:00<00:10, 10.11it/s, GPU RAM: 3.50 G/8.00 G]:   8%|█▉                        | 9/120 [00:01<00:10, 10.11it/s, GPU RAM: 3.50 G/8.00 G]:   8%|█▉                        | 9/120 [00:01<00:10, 10.11it/s, GPU RAM: 3.50 G/8.00 G]:   9%|██▎                      | 11/120 [00:01<00:10, 10.44it/s, GPU RAM: 3.50 G/8.00 G]:   9%|██▎                      | 11/120 [00:01<00:10, 10.44it/s, GPU RAM: 3.50 G/8.00 G]:   9%|██▎                      | 11/120 [00:01<00:10, 10.44it/s, GPU RAM: 3.50 G/8.00 G]:  11%|██▋                      | 13/120 [00:01<00:10, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  11%|██▋                      | 13/120 [00:01<00:10, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  11%|██▋                      | 13/120 [00:01<00:10, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  12%|███▏                     | 15/120 [00:01<00:09, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  12%|███▏                     | 15/120 [00:01<00:09, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  12%|███▏                     | 15/120 [00:01<00:09, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  14%|███▌                     | 17/120 [00:01<00:09, 10.69it/s, GPU RAM: 3.50 G/8.00 G]:  14%|███▌                     | 17/120 [00:01<00:09, 10.69it/s, GPU RAM: 3.50 G/8.00 G]:  14%|███▌                     | 17/120 [00:01<00:09, 10.69it/s, GPU RAM: 3.50 G/8.00 G]:  16%|███▉                     | 19/120 [00:01<00:09, 10.79it/s, GPU RAM: 3.50 G/8.00 G]:  16%|███▉                     | 19/120 [00:01<00:09, 10.79it/s, GPU RAM: 3.50 G/8.00 G]:  16%|███▉                     | 19/120 [00:02<00:09, 10.79it/s, GPU RAM: 3.50 G/8.00 G]:  18%|████▍                    | 21/120 [00:02<00:09, 10.87it/s, GPU RAM: 3.50 G/8.00 G]:  18%|████▍                    | 21/120 [00:02<00:09, 10.87it/s, GPU RAM: 3.50 G/8.00 G]:  18%|████▍                    | 21/120 [00:02<00:09, 10.87it/s, GPU RAM: 3.50 G/8.00 G]:  19%|████▊                    | 23/120 [00:02<00:08, 10.82it/s, GPU RAM: 3.50 G/8.00 G]:  19%|████▊                    | 23/120 [00:02<00:08, 10.82it/s, GPU RAM: 3.50 G/8.00 G]:  19%|████▊                    | 23/120 [00:02<00:08, 10.82it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▏                   | 25/120 [00:02<00:08, 10.81it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▏                   | 25/120 [00:02<00:08, 10.81it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▏                   | 25/120 [00:02<00:08, 10.81it/s, GPU RAM: 3.50 G/8.00 G]:  22%|█████▋                   | 27/120 [00:02<00:08, 10.81it/s, GPU RAM: 3.50 G/8.00 G]:  22%|█████▋                   | 27/120 [00:02<00:08, 10.81it/s, GPU RAM: 3.50 G/8.00 G]:  22%|█████▋                   | 27/120 [00:02<00:08, 10.81it/s, GPU RAM: 3.50 G/8.00 G]:  24%|██████                   | 29/120 [00:02<00:08, 10.88it/s, GPU RAM ...
# 27 Jan 19:14    INFO  epoch 0 training [time: 11.15s, train loss: 1232.2436]
# Evaluate   :   0%|                                                           | 0/61 [00:00<?, ?it/s]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 23.64it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 23.64it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 23.64it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 23.64it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:02, 26.72it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:02, 26.72it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:02, 26.72it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:02, 26.72it/s, GPU RAM: 3.50 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:01, 27.46it/s, GPU RAM: 3.50 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:01, 27.46it/s, GPU RAM: 3.50 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:01, 27.46it/s, GPU RAM: 3.50 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:01, 27.46it/s, GPU RAM: 3.50 G/8.00 G]:  20%|█████                     | 12/61 [00:00<00:01, 28.11it/s, GPU RAM: 3.50 G/8.00 G]:  20%|█████                     | 12/61 [00:00<00:01, 28.11it/s, GPU RAM: 3.50 G/8.00 G]:  20%|█████                     | 12/61 [00:00<00:01, 28.11it/s, GPU RAM: 3.50 G/8.00 G]:  20%|█████                     | 12/61 [00:00<00:01, 28.11it/s, GPU RAM: 3.50 G/8.00 G]:  20%|█████                     | 12/61 [00:00<00:01, 28.11it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.96it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.96it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.96it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.96it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.96it/s, GPU RAM: 3.50 G/8.00 G]:  33%|████████▌                 | 20/61 [00:00<00:01, 28.56it/s, GPU RAM: 3.50 G/8.00 G]:  33%|████████▌                 | 20/61 [00:00<00:01, 28.56it/s, GPU RAM: 3.50 G/8.00 G]:  33%|████████▌                 | 20/61 [00:00<00:01, 28.56it/s, GPU RAM: 3.50 G/8.00 G]:  33%|████████▌                 | 20/61 [00:00<00:01, 28.56it/s, GPU RAM: 3.50 G/8.00 G]:  38%|█████████▊                | 23/61 [00:00<00:01, 28.37it/s, GPU RAM: 3.50 G/8.00 G]:  38%|█████████▊                | 23/61 [00:00<00:01, 28.37it/s, GPU RAM: 3.50 G/8.00 G]:  38%|█████████▊                | 23/61 [00:00<00:01, 28.37it/s, GPU RAM: 3.50 G/8.00 G]:  38%|█████████▊                | 23/61 [00:00<00:01, 28.37it/s, GPU RAM: 3.50 G/8.00 G]:  43%|███████████               | 26/61 [00:00<00:01, 27.28it/s, GPU RAM: 3.50 G/8.00 G]:  43%|███████████               | 26/61 [00:00<00:01, 27.28it/s, GPU RAM: 3.50 G/8.00 G]:  43%|███████████               | 26/61 [00:00<00:01, 27.28it/s, GPU RAM: 3.50 G/8.00 G]:  43%|███████████               | 26/61 [00:01<00:01, 27.28it/s, GPU RAM: 3.50 G/8.00 G]:  48%|████████████▎             | 29/61 [00:01<00:01, 26.92it/s, GPU RAM: 3.50 G/8.00 G]:  48%|████████████▎             | 29/61 [00:01<00:01, 26.92it/s, GPU RAM: 3.50 G/8.00 G]:  48%|████████████▎             | 29/61 [00:01<00:01, 26.92it/s, GPU RAM: 3.50 G/8.00 G]:  48%|████████████▎             | 29/61 [00:01<00:01, 26.92it/s, GPU RAM: 3.50 G/8.00 G]:  52%|█████████████▋            | 32/61 [00:01<00:01, 24.65it/s, GPU RAM: 3.50 G/8.00 G]:  52%|█████████████▋            | 32/61 [00:01<00:01, 24.65it/s, GPU RAM: 3.50 G/8.00 G]:  52%|█████████████▋            | 32/61 [00:01<00:01, 24.65it/s, GPU RAM ...
# 27 Jan 19:18    INFO  epoch 0 evaluating [time: 247.41s, valid_score: 0.004500]
# 27 Jan 19:18    INFO  valid result:
# recall@1 : 0.0018    recall@10 : 0.0138    recall@50 : 0.0506    recall@100 : 0.0844    mrr@1 : 0.0018    mrr@10 : 0.0045    mrr@50 : 0.0062    mrr@100 : 0.0067    ndcg@1 : 0.0018    ndcg@10 : 0.0067    ndcg@50 : 0.0147    ndcg@100 : 0.0201    hit@1 : 0.0018    hit@10 : 0.0138    hit@50 : 0.0506    hit@100 : 0.0844    precision@1 : 0.0018    precision@10 : 0.0014    precision@50 : 0.001    precision@100 : 0.0008    averagepopularity@1 : 1244.6213    averagepopularity@10 : 831.6369    averagepopularity@50 : 569.5466    averagepopularity@100 : 441.1186    tailpercentage@1 : 0.0    tailpercentage@10 : 0.0023    tailpercentage@50 : 0.0068    tailpercentage@100 : 0.0085    itemcoverage@1 : 0.0002    itemcoverage@10 : 0.002    itemcoverage@50 : 0.0079    itemcoverage@100 : 0.0144
# 27 Jan 19:18    INFO  Saving current: saved\GRU4Rec-Jan-27-2024_19-13-51.pth
# 27 Jan 19:18    INFO  Loading model structure and parameters from saved\GRU4Rec-Jan-27-2024_19-13-51.pth
# Evaluate   :   0%|                                                          | 0/158 [00:00<?, ?it/s]:   0%|                                  | 0/158 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:25,  6.04it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:25,  6.04it/s, GPU RAM: 3.51 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:25,  6.04it/s, GPU RAM: 3.51 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:25,  6.04it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:09, 15.76it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:09, 15.76it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:09, 15.76it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:09, 15.76it/s, GPU RAM: 3.51 G/8.00 G]:   4%|█▏                        | 7/158 [00:00<00:07, 20.98it/s, GPU RAM: 3.51 G/8.00 G]:   4%|█▏                        | 7/158 [00:00<00:07, 20.98it/s, GPU RAM: 3.51 G/8.00 G]:   4%|█▏                        | 7/158 [00:00<00:07, 20.98it/s, GPU RAM: 3.51 G/8.00 G]:   4%|█▏                        | 7/158 [00:00<00:07, 20.98it/s, GPU RAM: 3.51 G/8.00 G]:   6%|█▌                       | 10/158 [00:00<00:06, 23.43it/s, GPU RAM: 3.51 G/8.00 G]:   6%|█▌                       | 10/158 [00:00<00:06, 23.43it/s, GPU RAM: 3.51 G/8.00 G]:   6%|█▌                       | 10/158 [00:00<00:06, 23.43it/s, GPU RAM: 3.51 G/8.00 G]:   6%|█▌                       | 10/158 [00:00<00:06, 23.43it/s, GPU RAM: 3.51 G/8.00 G]:   8%|██                       | 13/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|██                       | 13/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|██                       | 13/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|██                       | 13/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|██                       | 13/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:  11%|██▋                      | 17/158 [00:00<00:05, 27.59it/s, GPU RAM: 3.51 G/8.00 G]:  11%|██▋                      | 17/158 [00:00<00:05, 27.59it/s, GPU RAM: 3.51 G/8.00 G]:  11%|██▋                      | 17/158 [00:00<00:05, 27.59it/s, GPU RAM: 3.51 G/8.00 G]:  11%|██▋                      | 17/158 [00:00<00:05, 27.59it/s, GPU RAM: 3.51 G/8.00 G]:  13%|███▏                     | 20/158 [00:00<00:05, 26.66it/s, GPU RAM: 3.51 G/8.00 G]:  13%|███▏                     | 20/158 [00:00<00:05, 26.66it/s, GPU RAM: 3.51 G/8.00 G]:  13%|███▏                     | 20/158 [00:00<00:05, 26.66it/s, GPU RAM: 3.51 G/8.00 G]:  13%|███▏                     | 20/158 [00:00<00:05, 26.66it/s, GPU RAM: 3.51 G/8.00 G]:  15%|███▋                     | 23/158 [00:00<00:05, 26.49it/s, GPU RAM: 3.51 G/8.00 G]:  15%|███▋                     | 23/158 [00:00<00:05, 26.49it/s, GPU RAM: 3.51 G/8.00 G]:  15%|███▋                     | 23/158 [00:00<00:05, 26.49it/s, GPU RAM: 3.51 G/8.00 G]:  15%|███▋                     | 23/158 [00:01<00:05, 26.49it/s, GPU RAM: 3.51 G/8.00 G]:  16%|████                     | 26/158 [00:01<00:04, 27.34it/s, GPU RAM: 3.51 G/8.00 G]:  16%|████                     | 26/158 [00:01<00:04, 27.34it/s, GPU RAM: 3.51 G/8.00 G]:  16%|████                     | 26/158 [00:01<00:04, 27.34it/s, GPU RAM: 3.51 G/8.00 G]:  16%|████                     | 26/158 [00:01<00:04, 27.34it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▌                    | 29/158 [00:01<00:04, 27.03it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▌                    | 29/158 [00:01<00:04, 27.03it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▌                    | 29/158 [00:01<00:04, 27.03it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▌                    | 29/158 [00:01<00:04, 27.03it/s, GPU RAM: 3.51 G/8.00 G]:  20%|█████                    | 32/158 [00:01<00:04, 26.42it/s, GPU RAM: 3.51 G/8.00 G]:  20%|█████                    | 32/158 [00:01<00:04, 26.42it/s, GPU RAM ...
# 27 Jan 19:28    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     1.50 %     |
# +-------------+----------------+
# | GPU         | 3.51 G/8.00 G  |
# +-------------+----------------+
# | Memory      | 2.79 G/15.21 G |
# +-------------+----------------+
# 27 Jan 19:28    INFO  best valid : OrderedDict([('recall@1', 0.0018), ('recall@10', 0.0138), ('recall@50', 0.0506), ('recall@100', 0.0844), ('mrr@1', 0.0018), ('mrr@10', 0.0045), ('mrr@50', 0.0062), ('mrr@100', 0.0067), ('ndcg@1', 0.0018), ('ndcg@10', 0.0067), ('ndcg@50', 0.0147), ('ndcg@100', 0.0201), ('hit@1', 0.0018), ('hit@10', 0.0138), ('hit@50', 0.0506), ('hit@100', 0.0844), ('precision@1', 0.0018), ('precision@10', 0.0014), ('precision@50', 0.001), ('precision@100', 0.0008), ('averagepopularity@1', 1244.6213), ('averagepopularity@10', 831.6369), ('averagepopularity@50', 569.5466), ('averagepopularity@100', 441.1186), ('tailpercentage@1', 0.0), ('tailpercentage@10', 0.0023), ('tailpercentage@50', 0.0068), ('tailpercentage@100', 0.0085), ('itemcoverage@1', 0.0002), ('itemcoverage@10', 0.002), ('itemcoverage@50', 0.0079), ('itemcoverage@100', 0.0144)])
# 27 Jan 19:28    INFO  test result: OrderedDict([('recall@1', 0.0029), ('recall@10', 0.0188), ('recall@50', 0.0583), ('recall@100', 0.0878), ('mrr@1', 0.0029), ('mrr@10', 0.0074), ('mrr@50', 0.0091), ('mrr@100', 0.0096), ('ndcg@1', 0.0029), ('ndcg@10', 0.01), ('ndcg@50', 0.0186), ('ndcg@100', 0.0234), ('hit@1', 0.0029), ('hit@10', 0.0188), ('hit@50', 0.0583), ('hit@100', 0.0878), ('precision@1', 0.0029), ('precision@10', 0.0019), ('precision@50', 0.0012), ('precision@100', 0.0009), ('averagepopularity@1', 1245.4177), ('averagepopularity@10', 832.146), ('averagepopularity@50', 569.8926), ('averagepopularity@100', 441.3708), ('tailpercentage@1', 0.0), ('tailpercentage@10', 0.0023), ('tailpercentage@50', 0.0068), ('tailpercentage@100', 0.0083), ('itemcoverage@1', 0.0003), ('itemcoverage@10', 0.0022), ('itemcoverage@50', 0.0082), ('itemcoverage@100', 0.0149)])

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/GRU4Rec_test.json", indent=2)

# %% [markdown]
# # BERT4Rec

# %%
dict_results = run_recbole(model="BERT4Rec", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')
# Out:
# 27 Jan 19:35    INFO  ['c:\\Users\\petru\\Documents\\python_envs\\recbole\\lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\petru\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-62000Fd8kLC7w33i.json']
# 27 Jan 19:35    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = ..\RECEIPT_LINES
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 1
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'AveragePopularity', 'TailPercentage', 'ItemCoverage']
# topk = [1, 10, 50, 100]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 1024
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = Key_receipt
# ITEM_ID_FIELD = Key_product
# RATING_FIELD = rating
# TIME_FIELD = TS_T_RECEIPT
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product'], 'item': ['D_PRODUCT', 'K_PRODUCT_TYPE', 'Key_product', 'hierachy']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 7
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = mask_itemseq
# n_layers = 2
# n_heads = 2
# hidden_size = 128
# inner_size = 256
# hidden_dropout_prob = 0.2
# attn_dropout_prob = 0.2
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# mask_ratio = 0.2
# loss_type = CE
# ft_ratio = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# reproducibility' = True
# D_PRODUCT_FIELD = D_PRODUCT
# device = cuda
# K_PRODUCT_TYPE_FIELD = K_PRODUCT_TYPE
# Key_receipt_FIELD = Key_receipt
# LINE_NUM_FIELD = LINE_NUM
# QUANTITY_FIELD = QUANTITY
# Q_AMOUNT_FIELD = Q_AMOUNT
# Q_DISCOUNT_AMOUNT_FIELD = Q_DISCOUNT_AMOUNT
# dropout_prob = 0.3
# embedding_size = 64
# num_layers = 1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\recbole\data\dataset\dataset.py:1217: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   split_point = np.cumsum(feat[field].agg(len))[:-1]
# 27 Jan 19:35    INFO  RECEIPT_LINES
# The number of users: 1103980
# Average actions of users: 1.6437604338488323
# The number of items: 62763
# Average actions of items: 28.91362607947484
# The number of inters: 1814677
# The sparsity of the dataset: 99.99738100641315%
# Remain Fields: ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product', 'D_PRODUCT', 'K_PRODUCT_TYPE']
# 27 Jan 19:36    INFO  [Training]: train_batch_size = [4096] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 27 Jan 19:36    INFO  [Evaluation]: eval_batch_size = [1024] eval_args: [{'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}]
# 27 Jan 19:36    INFO  BERT4Rec(
#   (item_embedding): Embedding(62764, 128, padding_idx=0)
#   (position_embedding): Embedding(7, 128)
#   (trm_encoder): TransformerEncoder(
#     (layer): ModuleList(
#       (0-1): 2 x TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=128, out_features=128, bias=True)
#           (key): Linear(in_features=128, out_features=128, bias=True)
#           (value): Linear(in_features=128, out_features=128, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (dense): Linear(in_features=128, out_features=128, bias=True)
#           (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.2, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=128, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=128, bias=True)
#           (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (output_ffn): Linear(in_features=128, out_features=128, bias=True)
#   (output_gelu): GELU(approximate='none')
#   (output_ln): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
# )
# Trainable parameters: 8379435
# 27 Jan 19:36    INFO  FLOPs: 1962928.0
# Train     0:   0%|                                                          | 0/120 [00:00<?, ?it/s]:   0%|                                  | 0/120 [00:00<?, ?it/s, GPU RAM: 3.74 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:03,  1.87it/s, GPU RAM: 3.74 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:03,  1.87it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▍                         | 2/120 [00:00<00:43,  2.73it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▍                         | 2/120 [00:01<00:43,  2.73it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▋                         | 3/120 [00:01<00:35,  3.27it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▋                         | 3/120 [00:01<00:35,  3.27it/s, GPU RAM: 3.74 G/8.00 G]:   3%|▊                         | 4/120 [00:01<00:33,  3.51it/s, GPU RAM: 3.74 G/8.00 G]:   3%|▊                         | 4/120 [00:01<00:33,  3.51it/s, GPU RAM: 3.74 G/8.00 G]:   4%|█                         | 5/120 [00:01<00:31,  3.70it/s, GPU RAM: 3.74 G/8.00 G]:   4%|█                         | 5/120 [00:01<00:31,  3.70it/s, GPU RAM: 3.74 G/8.00 G]:   5%|█▎                        | 6/120 [00:01<00:29,  3.83it/s, GPU RAM: 3.74 G/8.00 G]:   5%|█▎                        | 6/120 [00:01<00:29,  3.83it/s, GPU RAM: 3.74 G/8.00 G]:   6%|█▌                        | 7/120 [00:01<00:28,  3.95it/s, GPU RAM: 3.74 G/8.00 G]:   6%|█▌                        | 7/120 [00:02<00:28,  3.95it/s, GPU RAM: 3.74 G/8.00 G]:   7%|█▋                        | 8/120 [00:02<00:27,  4.01it/s, GPU RAM: 3.74 G/8.00 G]:   7%|█▋                        | 8/120 [00:02<00:27,  4.01it/s, GPU RAM: 3.74 G/8.00 G]:   8%|█▉                        | 9/120 [00:02<00:27,  4.00it/s, GPU RAM: 3.74 G/8.00 G]:   8%|█▉                        | 9/120 [00:02<00:27,  4.00it/s, GPU RAM: 3.74 G/8.00 G]:   8%|██                       | 10/120 [00:02<00:27,  3.93it/s, GPU RAM: 3.74 G/8.00 G]:   8%|██                       | 10/120 [00:02<00:27,  3.93it/s, GPU RAM: 3.74 G/8.00 G]:   9%|██▎                      | 11/120 [00:02<00:27,  4.03it/s, GPU RAM: 3.74 G/8.00 G]:   9%|██▎                      | 11/120 [00:03<00:27,  4.03it/s, GPU RAM: 3.74 G/8.00 G]:  10%|██▌                      | 12/120 [00:03<00:26,  4.05it/s, GPU RAM: 3.74 G/8.00 G]:  10%|██▌                      | 12/120 [00:03<00:26,  4.05it/s, GPU RAM: 3.74 G/8.00 G]:  11%|██▋                      | 13/120 [00:03<00:26,  4.09it/s, GPU RAM: 3.74 G/8.00 G]:  11%|██▋                      | 13/120 [00:03<00:26,  4.09it/s, GPU RAM: 3.74 G/8.00 G]:  12%|██▉                      | 14/120 [00:03<00:26,  4.07it/s, GPU RAM: 3.74 G/8.00 G]:  12%|██▉                      | 14/120 [00:03<00:26,  4.07it/s, GPU RAM: 3.74 G/8.00 G]:  12%|███▏                     | 15/120 [00:03<00:25,  4.08it/s, GPU RAM: 3.74 G/8.00 G]:  12%|███▏                     | 15/120 [00:04<00:25,  4.08it/s, GPU RAM: 3.74 G/8.00 G]:  13%|███▎                     | 16/120 [00:04<00:24,  4.21it/s, GPU RAM: 3.74 G/8.00 G]:  13%|███▎                     | 16/120 [00:04<00:24,  4.21it/s, GPU RAM: 3.74 G/8.00 G]:  14%|███▌                     | 17/120 [00:04<00:24,  4.13it/s, GPU RAM: 3.74 G/8.00 G]:  14%|███▌                     | 17/120 [00:04<00:24,  4.13it/s, GPU RAM: 3.74 G/8.00 G]:  15%|███▊                     | 18/120 [00:04<00:24,  4.09it/s, GPU RAM: 3.74 G/8.00 G]:  15%|███▊                     | 18/120 [00:04<00:24,  4.09it/s, GPU RAM: 3.74 G/8.00 G]:  16%|███▉                     | 19/120 [00:04<00:24,  4.11it/s, GPU RAM: 3.74 G/8.00 G]:  16%|███▉                     | 19/120 [00:05<00:24,  4.11it/s, GPU RAM: 3.74 G/8.00 G]:  17%|████▏                    | 20/120 [00:05<00:23,  4.17it/s, GPU RAM: 3.74 G/8.00 G]:  17%|████▏                    | 20/120 [00:05<00:23,  4.17it/s, GPU RAM: 3.74 G/8.00 G]:  18%|████▍                    | 21/120 [00:05<00:23,  4.13it/s, GPU RAM: 3.74 G/8.00 G]:  18%|████▍                    | 21/120 [00:05<00:23,  4.13it/s, GPU RAM: 3.74 G/8.00 G]:  18%|████▌                    | 22/120 [00:05<00:24,  4.06it/s, GPU RAM ...
# 27 Jan 19:37    INFO  epoch 0 training [time: 32.39s, train loss: 1171.6022]
# Evaluate   :   0%|                                                           | 0/61 [00:00<?, ?it/s]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▍                          | 1/61 [00:00<00:06,  9.32it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▍                          | 1/61 [00:00<00:06,  9.32it/s, GPU RAM: 3.74 G/8.00 G]:   2%|▍                          | 1/61 [00:00<00:06,  9.32it/s, GPU RAM: 3.74 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:05, 10.81it/s, GPU RAM: 3.74 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:05, 10.81it/s, GPU RAM: 3.74 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:05, 10.81it/s, GPU RAM: 3.74 G/8.00 G]:   8%|██▏                        | 5/61 [00:00<00:04, 11.20it/s, GPU RAM: 3.74 G/8.00 G]:   8%|██▏                        | 5/61 [00:00<00:04, 11.20it/s, GPU RAM: 3.74 G/8.00 G]:   8%|██▏                        | 5/61 [00:00<00:04, 11.20it/s, GPU RAM: 3.74 G/8.00 G]:  11%|███                        | 7/61 [00:00<00:04, 11.32it/s, GPU RAM: 3.74 G/8.00 G]:  11%|███                        | 7/61 [00:00<00:04, 11.32it/s, GPU RAM: 3.74 G/8.00 G]:  11%|███                        | 7/61 [00:00<00:04, 11.32it/s, GPU RAM: 3.74 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:04, 11.03it/s, GPU RAM: 3.74 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:04, 11.03it/s, GPU RAM: 3.74 G/8.00 G]:  15%|███▉                       | 9/61 [00:00<00:04, 11.03it/s, GPU RAM: 3.74 G/8.00 G]:  18%|████▋                     | 11/61 [00:00<00:04, 11.19it/s, GPU RAM: 3.74 G/8.00 G]:  18%|████▋                     | 11/61 [00:01<00:04, 11.19it/s, GPU RAM: 3.74 G/8.00 G]:  18%|████▋                     | 11/61 [00:01<00:04, 11.19it/s, GPU RAM: 3.74 G/8.00 G]:  21%|█████▌                    | 13/61 [00:01<00:04, 11.10it/s, GPU RAM: 3.74 G/8.00 G]:  21%|█████▌                    | 13/61 [00:01<00:04, 11.10it/s, GPU RAM: 3.74 G/8.00 G]:  21%|█████▌                    | 13/61 [00:01<00:04, 11.10it/s, GPU RAM: 3.74 G/8.00 G]:  25%|██████▍                   | 15/61 [00:01<00:04, 11.07it/s, GPU RAM: 3.74 G/8.00 G]:  25%|██████▍                   | 15/61 [00:01<00:04, 11.07it/s, GPU RAM: 3.74 G/8.00 G]:  25%|██████▍                   | 15/61 [00:01<00:04, 11.07it/s, GPU RAM: 3.74 G/8.00 G]:  28%|███████▏                  | 17/61 [00:01<00:04, 10.32it/s, GPU RAM: 3.74 G/8.00 G]:  28%|███████▏                  | 17/61 [00:01<00:04, 10.32it/s, GPU RAM: 3.74 G/8.00 G]:  28%|███████▏                  | 17/61 [00:01<00:04, 10.32it/s, GPU RAM: 3.74 G/8.00 G]:  31%|████████                  | 19/61 [00:01<00:04,  9.66it/s, GPU RAM: 3.74 G/8.00 G]:  31%|████████                  | 19/61 [00:01<00:04,  9.66it/s, GPU RAM: 3.74 G/8.00 G]:  33%|████████▌                 | 20/61 [00:01<00:04,  9.55it/s, GPU RAM: 3.74 G/8.00 G]:  33%|████████▌                 | 20/61 [00:01<00:04,  9.55it/s, GPU RAM: 3.74 G/8.00 G]:  34%|████████▉                 | 21/61 [00:02<00:04,  9.11it/s, GPU RAM: 3.74 G/8.00 G]:  34%|████████▉                 | 21/61 [00:02<00:04,  9.11it/s, GPU RAM: 3.74 G/8.00 G]:  36%|█████████▍                | 22/61 [00:02<00:04,  9.00it/s, GPU RAM: 3.74 G/8.00 G]:  36%|█████████▍                | 22/61 [00:02<00:04,  9.00it/s, GPU RAM: 3.74 G/8.00 G]:  38%|█████████▊                | 23/61 [00:02<00:04,  8.88it/s, GPU RAM: 3.74 G/8.00 G]:  38%|█████████▊                | 23/61 [00:02<00:04,  8.88it/s, GPU RAM: 3.74 G/8.00 G]:  39%|██████████▏               | 24/61 [00:02<00:04,  8.73it/s, GPU RAM: 3.74 G/8.00 G]:  39%|██████████▏               | 24/61 [00:02<00:04,  8.73it/s, GPU RAM: 3.74 G/8.00 G]:  41%|██████████▋               | 25/61 [00:02<00:04,  8.77it/s, GPU RAM: 3.74 G/8.00 G]:  41%|██████████▋               | 25/61 [00:02<00:04,  8.77it/s, GPU RAM: 3.74 G/8.00 G]:  43%|███████████               | 26/61 [00:02<00:03,  9.00it/s, GPU RAM: 3.74 G/8.00 G]:  43%|███████████               | 26/61 [00:02<00:03,  9.00it/s, GPU RAM ...

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/BERT4Rec_test.json", indent=2)

# %% [markdown]
# # Caser

# %%
dict_results = run_recbole(model="Caser", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/Caser_test.json", indent=2)

# %% [markdown]
# # TransRec

# %%
dict_results = run_recbole(model="TransRec", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/TransRec_test.json", indent=2)
