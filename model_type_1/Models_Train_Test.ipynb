# %%
from recbole.quick_start import run_recbole, load_data_and_model
from recbole.utils import get_trainer

# %% [markdown]
# # GRU4Rec

# %%
dict_results = run_recbole(model="GRU4Rec", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')
# Out:
# 31 Jan 09:56    INFO  ['c:\\Users\\petru\\Documents\\python_envs\\recbole\\lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\petru\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-25192uoQbXmF8WFHB.json']
# 31 Jan 09:56    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = ..\RECEIPT_LINES
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 1
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'AveragePopularity', 'TailPercentage', 'ItemCoverage']
# topk = [1, 10, 50, 100]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 1024
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = Key_receipt
# ITEM_ID_FIELD = Key_product
# RATING_FIELD = rating
# TIME_FIELD = TS_T_RECEIPT
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product'], 'item': ['D_PRODUCT', 'K_PRODUCT_TYPE', 'Key_product', 'hierachy']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 7
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# hidden_size = 128
# num_layers = 1
# dropout_prob = 0.3
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# reproducibility' = True
# D_PRODUCT_FIELD = D_PRODUCT
# device = cuda
# K_PRODUCT_TYPE_FIELD = K_PRODUCT_TYPE
# Key_receipt_FIELD = Key_receipt
# LINE_NUM_FIELD = LINE_NUM
# QUANTITY_FIELD = QUANTITY
# Q_AMOUNT_FIELD = Q_AMOUNT
# Q_DISCOUNT_AMOUNT_FIELD = Q_DISCOUNT_AMOUNT
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\recbole\data\dataset\dataset.py:1217: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   split_point = np.cumsum(feat[field].agg(len))[:-1]
# 31 Jan 09:57    INFO  RECEIPT_LINES
# The number of users: 1103980
# Average actions of users: 1.6437604338488323
# The number of items: 62763
# Average actions of items: 28.91362607947484
# The number of inters: 1814677
# The sparsity of the dataset: 99.99738100641315%
# Remain Fields: ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product', 'D_PRODUCT', 'K_PRODUCT_TYPE']
# 31 Jan 09:57    INFO  [Training]: train_batch_size = [4096] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 31 Jan 09:57    INFO  [Evaluation]: eval_batch_size = [1024] eval_args: [{'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}]
# 31 Jan 09:57    INFO  GRU4Rec(
#   (item_embedding): Embedding(62763, 64, padding_idx=0)
#   (emb_dropout): Dropout(p=0.3, inplace=False)
#   (gru_layers): GRU(64, 128, bias=False, batch_first=True)
#   (dense): Linear(in_features=128, out_features=64, bias=True)
#   (loss_fct): CrossEntropyLoss()
# )
# Trainable parameters: 4098816
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\torch\nn\modules\rnn.py:1102: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at ..\aten\src\ATen\native\cudnn\RNN.cpp:982.)
#   result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
# 31 Jan 09:57    INFO  FLOPs: 580224.0
# Train     0:   0%|                                                          | 0/120 [00:00<?, ?it/s]:   0%|                                  | 0/120 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:07,  1.75it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:07,  1.75it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:07,  1.75it/s, GPU RAM: 3.50 G/8.00 G]:   2%|▋                         | 3/120 [00:00<00:25,  4.62it/s, GPU RAM: 3.50 G/8.00 G]:   2%|▋                         | 3/120 [00:00<00:25,  4.62it/s, GPU RAM: 3.50 G/8.00 G]:   2%|▋                         | 3/120 [00:00<00:25,  4.62it/s, GPU RAM: 3.50 G/8.00 G]:   4%|█                         | 5/120 [00:00<00:17,  6.49it/s, GPU RAM: 3.50 G/8.00 G]:   4%|█                         | 5/120 [00:01<00:17,  6.49it/s, GPU RAM: 3.50 G/8.00 G]:   4%|█                         | 5/120 [00:01<00:17,  6.49it/s, GPU RAM: 3.50 G/8.00 G]:   6%|█▌                        | 7/120 [00:01<00:14,  7.74it/s, GPU RAM: 3.50 G/8.00 G]:   6%|█▌                        | 7/120 [00:01<00:14,  7.74it/s, GPU RAM: 3.50 G/8.00 G]:   6%|█▌                        | 7/120 [00:01<00:14,  7.74it/s, GPU RAM: 3.50 G/8.00 G]:   8%|█▉                        | 9/120 [00:01<00:12,  8.63it/s, GPU RAM: 3.50 G/8.00 G]:   8%|█▉                        | 9/120 [00:01<00:12,  8.63it/s, GPU RAM: 3.50 G/8.00 G]:   8%|█▉                        | 9/120 [00:01<00:12,  8.63it/s, GPU RAM: 3.50 G/8.00 G]:   9%|██▎                      | 11/120 [00:01<00:11,  9.34it/s, GPU RAM: 3.50 G/8.00 G]:   9%|██▎                      | 11/120 [00:01<00:11,  9.34it/s, GPU RAM: 3.50 G/8.00 G]:   9%|██▎                      | 11/120 [00:01<00:11,  9.34it/s, GPU RAM: 3.50 G/8.00 G]:  11%|██▋                      | 13/120 [00:01<00:10,  9.89it/s, GPU RAM: 3.50 G/8.00 G]:  11%|██▋                      | 13/120 [00:01<00:10,  9.89it/s, GPU RAM: 3.50 G/8.00 G]:  11%|██▋                      | 13/120 [00:01<00:10,  9.89it/s, GPU RAM: 3.50 G/8.00 G]:  12%|███▏                     | 15/120 [00:01<00:10, 10.20it/s, GPU RAM: 3.50 G/8.00 G]:  12%|███▏                     | 15/120 [00:01<00:10, 10.20it/s, GPU RAM: 3.50 G/8.00 G]:  12%|███▏                     | 15/120 [00:02<00:10, 10.20it/s, GPU RAM: 3.50 G/8.00 G]:  14%|███▌                     | 17/120 [00:02<00:09, 10.45it/s, GPU RAM: 3.50 G/8.00 G]:  14%|███▌                     | 17/120 [00:02<00:09, 10.45it/s, GPU RAM: 3.50 G/8.00 G]:  14%|███▌                     | 17/120 [00:02<00:09, 10.45it/s, GPU RAM: 3.50 G/8.00 G]:  16%|███▉                     | 19/120 [00:02<00:09, 10.56it/s, GPU RAM: 3.50 G/8.00 G]:  16%|███▉                     | 19/120 [00:02<00:09, 10.56it/s, GPU RAM: 3.50 G/8.00 G]:  16%|███▉                     | 19/120 [00:02<00:09, 10.56it/s, GPU RAM: 3.50 G/8.00 G]:  18%|████▍                    | 21/120 [00:02<00:09, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  18%|████▍                    | 21/120 [00:02<00:09, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  18%|████▍                    | 21/120 [00:02<00:09, 10.64it/s, GPU RAM: 3.50 G/8.00 G]:  19%|████▊                    | 23/120 [00:02<00:09, 10.65it/s, GPU RAM: 3.50 G/8.00 G]:  19%|████▊                    | 23/120 [00:02<00:09, 10.65it/s, GPU RAM: 3.50 G/8.00 G]:  19%|████▊                    | 23/120 [00:02<00:09, 10.65it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▏                   | 25/120 [00:02<00:08, 10.71it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▏                   | 25/120 [00:02<00:08, 10.71it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▏                   | 25/120 [00:02<00:08, 10.71it/s, GPU RAM: 3.50 G/8.00 G]:  22%|█████▋                   | 27/120 [00:02<00:08, 10.80it/s, GPU RAM: 3.50 G/8.00 G]:  22%|█████▋                   | 27/120 [00:03<00:08, 10.80it/s, GPU RAM: 3.50 G/8.00 G]:  22%|█████▋                   | 27/120 [00:03<00:08, 10.80it/s, GPU RAM: 3.50 G/8.00 G]:  24%|██████                   | 29/120 [00:03<00:08, 10.86it/s, GPU RAM ...
# 31 Jan 09:57    INFO  epoch 0 training [time: 11.48s, train loss: 1232.2436]
# Evaluate   :   0%|                                                           | 0/61 [00:00<?, ?it/s]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 26.47it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 26.47it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 26.47it/s, GPU RAM: 3.50 G/8.00 G]:   5%|█▎                         | 3/61 [00:00<00:02, 26.47it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:01, 28.22it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:01, 28.22it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:01, 28.22it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:01, 28.22it/s, GPU RAM: 3.50 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:01, 28.22it/s, GPU RAM: 3.50 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:01, 28.85it/s, GPU RAM: 3.50 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:01, 28.85it/s, GPU RAM: 3.50 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:01, 28.85it/s, GPU RAM: 3.50 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:01, 28.85it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▌                    | 13/61 [00:00<00:01, 29.25it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▌                    | 13/61 [00:00<00:01, 29.25it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▌                    | 13/61 [00:00<00:01, 29.25it/s, GPU RAM: 3.50 G/8.00 G]:  21%|█████▌                    | 13/61 [00:00<00:01, 29.25it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.21it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.21it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.21it/s, GPU RAM: 3.50 G/8.00 G]:  26%|██████▊                   | 16/61 [00:00<00:01, 28.21it/s, GPU RAM: 3.50 G/8.00 G]:  31%|████████                  | 19/61 [00:00<00:01, 27.85it/s, GPU RAM: 3.50 G/8.00 G]:  31%|████████                  | 19/61 [00:00<00:01, 27.85it/s, GPU RAM: 3.50 G/8.00 G]:  31%|████████                  | 19/61 [00:00<00:01, 27.85it/s, GPU RAM: 3.50 G/8.00 G]:  31%|████████                  | 19/61 [00:00<00:01, 27.85it/s, GPU RAM: 3.50 G/8.00 G]:  36%|█████████▍                | 22/61 [00:00<00:01, 26.81it/s, GPU RAM: 3.50 G/8.00 G]:  36%|█████████▍                | 22/61 [00:00<00:01, 26.81it/s, GPU RAM: 3.50 G/8.00 G]:  36%|█████████▍                | 22/61 [00:00<00:01, 26.81it/s, GPU RAM: 3.50 G/8.00 G]:  36%|█████████▍                | 22/61 [00:00<00:01, 26.81it/s, GPU RAM: 3.50 G/8.00 G]:  41%|██████████▋               | 25/61 [00:00<00:01, 26.33it/s, GPU RAM: 3.50 G/8.00 G]:  41%|██████████▋               | 25/61 [00:00<00:01, 26.33it/s, GPU RAM: 3.50 G/8.00 G]:  41%|██████████▋               | 25/61 [00:00<00:01, 26.33it/s, GPU RAM: 3.50 G/8.00 G]:  41%|██████████▋               | 25/61 [00:00<00:01, 26.33it/s, GPU RAM: 3.50 G/8.00 G]:  46%|███████████▉              | 28/61 [00:01<00:01, 26.76it/s, GPU RAM: 3.50 G/8.00 G]:  46%|███████████▉              | 28/61 [00:01<00:01, 26.76it/s, GPU RAM: 3.50 G/8.00 G]:  46%|███████████▉              | 28/61 [00:01<00:01, 26.76it/s, GPU RAM: 3.50 G/8.00 G]:  46%|███████████▉              | 28/61 [00:01<00:01, 26.76it/s, GPU RAM: 3.50 G/8.00 G]:  51%|█████████████▏            | 31/61 [00:01<00:01, 26.31it/s, GPU RAM: 3.50 G/8.00 G]:  51%|█████████████▏            | 31/61 [00:01<00:01, 26.31it/s, GPU RAM: 3.50 G/8.00 G]:  51%|█████████████▏            | 31/61 [00:01<00:01, 26.31it/s, GPU RAM: 3.50 G/8.00 G]:  51%|█████████████▏            | 31/61 [00:01<00:01, 26.31it/s, GPU RAM ...
# 31 Jan 10:02    INFO  epoch 0 evaluating [time: 264.78s, valid_score: 0.004500]
# 31 Jan 10:02    INFO  valid result:
# recall@1 : 0.0018    recall@10 : 0.0138    recall@50 : 0.0506    recall@100 : 0.0844    mrr@1 : 0.0018    mrr@10 : 0.0045    mrr@50 : 0.0062    mrr@100 : 0.0067    ndcg@1 : 0.0018    ndcg@10 : 0.0067    ndcg@50 : 0.0147    ndcg@100 : 0.0201    hit@1 : 0.0018    hit@10 : 0.0138    hit@50 : 0.0506    hit@100 : 0.0844    precision@1 : 0.0018    precision@10 : 0.0014    precision@50 : 0.001    precision@100 : 0.0008    averagepopularity@1 : 1244.6213    averagepopularity@10 : 831.6369    averagepopularity@50 : 569.5466    averagepopularity@100 : 441.1186    tailpercentage@1 : 0.0    tailpercentage@10 : 0.0023    tailpercentage@50 : 0.0068    tailpercentage@100 : 0.0085    itemcoverage@1 : 0.0002    itemcoverage@10 : 0.002    itemcoverage@50 : 0.0079    itemcoverage@100 : 0.0144
# 31 Jan 10:02    INFO  Saving current: saved\GRU4Rec-Jan-31-2024_09-57-34.pth
# 31 Jan 10:02    INFO  Loading model structure and parameters from saved\GRU4Rec-Jan-31-2024_09-57-34.pth
# Evaluate   :   0%|                                                          | 0/158 [00:00<?, ?it/s]:   0%|                                  | 0/158 [00:00<?, ?it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:31,  4.97it/s, GPU RAM: 3.50 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:31,  4.97it/s, GPU RAM: 3.51 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:31,  4.97it/s, GPU RAM: 3.51 G/8.00 G]:   1%|▏                         | 1/158 [00:00<00:31,  4.97it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:10, 15.29it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:10, 15.29it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:10, 15.29it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:10, 15.29it/s, GPU RAM: 3.51 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:10, 15.29it/s, GPU RAM: 3.51 G/8.00 G]:   5%|█▎                        | 8/158 [00:00<00:06, 22.17it/s, GPU RAM: 3.51 G/8.00 G]:   5%|█▎                        | 8/158 [00:00<00:06, 22.17it/s, GPU RAM: 3.51 G/8.00 G]:   5%|█▎                        | 8/158 [00:00<00:06, 22.17it/s, GPU RAM: 3.51 G/8.00 G]:   5%|█▎                        | 8/158 [00:00<00:06, 22.17it/s, GPU RAM: 3.51 G/8.00 G]:   5%|█▎                        | 8/158 [00:00<00:06, 22.17it/s, GPU RAM: 3.51 G/8.00 G]:   8%|█▉                       | 12/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|█▉                       | 12/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|█▉                       | 12/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   8%|█▉                       | 12/158 [00:00<00:05, 25.35it/s, GPU RAM: 3.51 G/8.00 G]:   9%|██▎                      | 15/158 [00:00<00:05, 26.43it/s, GPU RAM: 3.51 G/8.00 G]:   9%|██▎                      | 15/158 [00:00<00:05, 26.43it/s, GPU RAM: 3.51 G/8.00 G]:   9%|██▎                      | 15/158 [00:00<00:05, 26.43it/s, GPU RAM: 3.51 G/8.00 G]:   9%|██▎                      | 15/158 [00:00<00:05, 26.43it/s, GPU RAM: 3.51 G/8.00 G]:   9%|██▎                      | 15/158 [00:00<00:05, 26.43it/s, GPU RAM: 3.51 G/8.00 G]:  12%|███                      | 19/158 [00:00<00:05, 27.79it/s, GPU RAM: 3.51 G/8.00 G]:  12%|███                      | 19/158 [00:00<00:05, 27.79it/s, GPU RAM: 3.51 G/8.00 G]:  12%|███                      | 19/158 [00:00<00:05, 27.79it/s, GPU RAM: 3.51 G/8.00 G]:  12%|███                      | 19/158 [00:00<00:05, 27.79it/s, GPU RAM: 3.51 G/8.00 G]:  14%|███▍                     | 22/158 [00:00<00:04, 28.10it/s, GPU RAM: 3.51 G/8.00 G]:  14%|███▍                     | 22/158 [00:00<00:04, 28.10it/s, GPU RAM: 3.51 G/8.00 G]:  14%|███▍                     | 22/158 [00:00<00:04, 28.10it/s, GPU RAM: 3.51 G/8.00 G]:  14%|███▍                     | 22/158 [00:00<00:04, 28.10it/s, GPU RAM: 3.51 G/8.00 G]:  16%|███▉                     | 25/158 [00:01<00:04, 28.00it/s, GPU RAM: 3.51 G/8.00 G]:  16%|███▉                     | 25/158 [00:01<00:04, 28.00it/s, GPU RAM: 3.51 G/8.00 G]:  16%|███▉                     | 25/158 [00:01<00:04, 28.00it/s, GPU RAM: 3.51 G/8.00 G]:  16%|███▉                     | 25/158 [00:01<00:04, 28.00it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▍                    | 28/158 [00:01<00:04, 27.46it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▍                    | 28/158 [00:01<00:04, 27.46it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▍                    | 28/158 [00:01<00:04, 27.46it/s, GPU RAM: 3.51 G/8.00 G]:  18%|████▍                    | 28/158 [00:01<00:04, 27.46it/s, GPU RAM: 3.51 G/8.00 G]:  20%|████▉                    | 31/158 [00:01<00:04, 27.38it/s, GPU RAM: 3.51 G/8.00 G]:  20%|████▉                    | 31/158 [00:01<00:04, 27.38it/s, GPU RAM: 3.51 G/8.00 G]:  20%|████▉                    | 31/158 [00:01<00:04, 27.38it/s, GPU RAM: 3.51 G/8.00 G]:  20%|████▉                    | 31/158 [00:01<00:04, 27.38it/s, GPU RAM ...
# 31 Jan 10:13    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     8.70 %     |
# +-------------+----------------+
# | GPU         | 3.51 G/8.00 G  |
# +-------------+----------------+
# | Memory      | 1.64 G/15.21 G |
# +-------------+----------------+
# 31 Jan 10:13    INFO  best valid : OrderedDict([('recall@1', 0.0018), ('recall@10', 0.0138), ('recall@50', 0.0506), ('recall@100', 0.0844), ('mrr@1', 0.0018), ('mrr@10', 0.0045), ('mrr@50', 0.0062), ('mrr@100', 0.0067), ('ndcg@1', 0.0018), ('ndcg@10', 0.0067), ('ndcg@50', 0.0147), ('ndcg@100', 0.0201), ('hit@1', 0.0018), ('hit@10', 0.0138), ('hit@50', 0.0506), ('hit@100', 0.0844), ('precision@1', 0.0018), ('precision@10', 0.0014), ('precision@50', 0.001), ('precision@100', 0.0008), ('averagepopularity@1', 1244.6213), ('averagepopularity@10', 831.6369), ('averagepopularity@50', 569.5466), ('averagepopularity@100', 441.1186), ('tailpercentage@1', 0.0), ('tailpercentage@10', 0.0023), ('tailpercentage@50', 0.0068), ('tailpercentage@100', 0.0085), ('itemcoverage@1', 0.0002), ('itemcoverage@10', 0.002), ('itemcoverage@50', 0.0079), ('itemcoverage@100', 0.0144)])
# 31 Jan 10:13    INFO  test result: OrderedDict([('recall@1', 0.0029), ('recall@10', 0.0188), ('recall@50', 0.0583), ('recall@100', 0.0878), ('mrr@1', 0.0029), ('mrr@10', 0.0074), ('mrr@50', 0.0091), ('mrr@100', 0.0096), ('ndcg@1', 0.0029), ('ndcg@10', 0.01), ('ndcg@50', 0.0186), ('ndcg@100', 0.0234), ('hit@1', 0.0029), ('hit@10', 0.0188), ('hit@50', 0.0583), ('hit@100', 0.0878), ('precision@1', 0.0029), ('precision@10', 0.0019), ('precision@50', 0.0012), ('precision@100', 0.0009), ('averagepopularity@1', 1245.4177), ('averagepopularity@10', 832.146), ('averagepopularity@50', 569.8926), ('averagepopularity@100', 441.3708), ('tailpercentage@1', 0.0), ('tailpercentage@10', 0.0023), ('tailpercentage@50', 0.0068), ('tailpercentage@100', 0.0083), ('itemcoverage@1', 0.0003), ('itemcoverage@10', 0.0022), ('itemcoverage@50', 0.0082), ('itemcoverage@100', 0.0149)])

# %%
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='saved\GRU4Rec-Jan-31-2024_09-57-34.pth',
)
# Out:
# 31 Jan 10:19    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = ..\RECEIPT_LINES
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 1
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'AveragePopularity', 'TailPercentage', 'ItemCoverage']
# topk = [1, 10, 50, 100]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 1024
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = Key_receipt
# ITEM_ID_FIELD = Key_product
# RATING_FIELD = rating
# TIME_FIELD = TS_T_RECEIPT
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product'], 'item': ['D_PRODUCT', 'K_PRODUCT_TYPE', 'Key_product', 'hierachy']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 7
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# hidden_size = 128
# num_layers = 1
# dropout_prob = 0.3
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# reproducibility' = True
# D_PRODUCT_FIELD = D_PRODUCT
# device = cuda
# K_PRODUCT_TYPE_FIELD = K_PRODUCT_TYPE
# Key_receipt_FIELD = Key_receipt
# LINE_NUM_FIELD = LINE_NUM
# QUANTITY_FIELD = QUANTITY
# Q_AMOUNT_FIELD = Q_AMOUNT
# Q_DISCOUNT_AMOUNT_FIELD = Q_DISCOUNT_AMOUNT
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\recbole\data\dataset\dataset.py:1217: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   split_point = np.cumsum(feat[field].agg(len))[:-1]
# 31 Jan 10:19    INFO  RECEIPT_LINES
# The number of users: 1103980
# Average actions of users: 1.6437604338488323
# The number of items: 62763
# Average actions of items: 28.91362607947484
# The number of inters: 1814677
# The sparsity of the dataset: 99.99738100641315%
# Remain Fields: ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product', 'D_PRODUCT', 'K_PRODUCT_TYPE']
# 31 Jan 10:19    INFO  [Training]: train_batch_size = [4096] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 31 Jan 10:19    INFO  [Evaluation]: eval_batch_size = [1024] eval_args: [{'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}]

# %%
import torch

index_ten = torch.IntTensor([dataset.token2id(field="Key_product", tokens="6482152")]).to(model.device)

# %%
index_ten
# Out:
# tensor([2], device='cuda:0', dtype=torch.int32)

# %%
model.item_embedding(index_ten)
# Out:
# tensor([[ 0.0644, -0.0728, -0.0609, -0.0662, -0.0010, -0.0682, -0.0493,  0.0613,
#           0.0469,  0.0526, -0.0657,  0.0631,  0.0829,  0.0639,  0.0186, -0.0040,
#           0.0583, -0.0530, -0.0712, -0.0404, -0.0381,  0.0561, -0.0497, -0.0242,
#           0.0259, -0.0752,  0.0586,  0.0452,  0.0610,  0.0553, -0.0735, -0.0627,
#           0.0052,  0.0603, -0.0658,  0.0729, -0.0272,  0.0198, -0.0742, -0.0788,
#          -0.0674, -0.0467, -0.0371,  0.0390, -0.0512,  0.0093,  0.0462,  0.0819,
#           0.0393, -0.0287, -0.0454,  0.0367, -0.0596,  0.0083, -0.0832,  0.0500,
#           0.0495, -0.0447,  0.0411, -0.0455,  0.0378,  0.0630, -0.0810, -0.0676]],
#        device='cuda:0', grad_fn=<EmbeddingBackward0>)

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/GRU4Rec_test.json", indent=2)

# %% [markdown]
# # BERT4Rec

# %%
dict_results = run_recbole(model="BERT4Rec", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')
# Out:
# 27 Jan 19:55    INFO  ['c:\\Users\\petru\\Documents\\python_envs\\recbole\\lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\petru\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-6200Uwj1CQ64vmez.json']
# 27 Jan 19:55    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = ..\RECEIPT_LINES
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 1
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'AveragePopularity', 'TailPercentage', 'ItemCoverage']
# topk = [1, 10, 50, 100]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 1024
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = Key_receipt
# ITEM_ID_FIELD = Key_product
# RATING_FIELD = rating
# TIME_FIELD = TS_T_RECEIPT
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product'], 'item': ['D_PRODUCT', 'K_PRODUCT_TYPE', 'Key_product', 'hierachy']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 7
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = mask_itemseq
# n_layers = 2
# n_heads = 2
# hidden_size = 128
# inner_size = 256
# hidden_dropout_prob = 0.2
# attn_dropout_prob = 0.2
# hidden_act = gelu
# layer_norm_eps = 1e-12
# initializer_range = 0.02
# mask_ratio = 0.2
# loss_type = CE
# ft_ratio = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# reproducibility' = True
# D_PRODUCT_FIELD = D_PRODUCT
# device = cuda
# K_PRODUCT_TYPE_FIELD = K_PRODUCT_TYPE
# Key_receipt_FIELD = Key_receipt
# LINE_NUM_FIELD = LINE_NUM
# QUANTITY_FIELD = QUANTITY
# Q_AMOUNT_FIELD = Q_AMOUNT
# Q_DISCOUNT_AMOUNT_FIELD = Q_DISCOUNT_AMOUNT
# dropout_prob = 0.3
# embedding_size = 64
# num_layers = 1
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# c:\Users\petru\Documents\python_envs\recbole\lib\site-packages\recbole\data\dataset\dataset.py:1217: FutureWarning: using <built-in function len> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   split_point = np.cumsum(feat[field].agg(len))[:-1]
# 27 Jan 19:55    INFO  RECEIPT_LINES
# The number of users: 1103980
# Average actions of users: 1.6437604338488323
# The number of items: 62763
# Average actions of items: 28.91362607947484
# The number of inters: 1814677
# The sparsity of the dataset: 99.99738100641315%
# Remain Fields: ['K_MEMBER', 'TS_T_RECEIPT', 'LINE_NUM', 'Key_receipt', 'QUANTITY', 'Q_AMOUNT', 'Q_DISCOUNT_AMOUNT', 'Key_product', 'D_PRODUCT', 'K_PRODUCT_TYPE']
# 27 Jan 19:56    INFO  [Training]: train_batch_size = [4096] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 27 Jan 19:56    INFO  [Evaluation]: eval_batch_size = [1024] eval_args: [{'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'Key_receipt', 'mode': {'valid': 'full', 'test': 'full'}}]
# 27 Jan 19:56    INFO  BERT4Rec(
#   (item_embedding): Embedding(62764, 128, padding_idx=0)
#   (position_embedding): Embedding(7, 128)
#   (trm_encoder): TransformerEncoder(
#     (layer): ModuleList(
#       (0-1): 2 x TransformerLayer(
#         (multi_head_attention): MultiHeadAttention(
#           (query): Linear(in_features=128, out_features=128, bias=True)
#           (key): Linear(in_features=128, out_features=128, bias=True)
#           (value): Linear(in_features=128, out_features=128, bias=True)
#           (softmax): Softmax(dim=-1)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (dense): Linear(in_features=128, out_features=128, bias=True)
#           (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#           (out_dropout): Dropout(p=0.2, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (dense_1): Linear(in_features=128, out_features=256, bias=True)
#           (dense_2): Linear(in_features=256, out_features=128, bias=True)
#           (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#   )
#   (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (output_ffn): Linear(in_features=128, out_features=128, bias=True)
#   (output_gelu): GELU(approximate='none')
#   (output_ln): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
# )
# Trainable parameters: 8379435
# 27 Jan 19:56    INFO  FLOPs: 1962928.0
# Train     0:   0%|                                                          | 0/120 [00:00<?, ?it/s]:   0%|                                  | 0/120 [00:00<?, ?it/s, GPU RAM: 4.47 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:17,  1.54it/s, GPU RAM: 4.47 G/8.00 G]:   1%|▏                         | 1/120 [00:00<01:17,  1.54it/s, GPU RAM: 4.47 G/8.00 G]:   2%|▍                         | 2/120 [00:00<00:49,  2.41it/s, GPU RAM: 4.47 G/8.00 G]:   2%|▍                         | 2/120 [00:01<00:49,  2.41it/s, GPU RAM: 4.47 G/8.00 G]:   2%|▋                         | 3/120 [00:01<00:39,  2.95it/s, GPU RAM: 4.47 G/8.00 G]:   2%|▋                         | 3/120 [00:01<00:39,  2.95it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▊                         | 4/120 [00:01<00:36,  3.18it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▊                         | 4/120 [00:01<00:36,  3.18it/s, GPU RAM: 4.47 G/8.00 G]:   4%|█                         | 5/120 [00:01<00:33,  3.43it/s, GPU RAM: 4.47 G/8.00 G]:   4%|█                         | 5/120 [00:01<00:33,  3.43it/s, GPU RAM: 4.47 G/8.00 G]:   5%|█▎                        | 6/120 [00:01<00:31,  3.62it/s, GPU RAM: 4.47 G/8.00 G]:   5%|█▎                        | 6/120 [00:02<00:31,  3.62it/s, GPU RAM: 4.47 G/8.00 G]:   6%|█▌                        | 7/120 [00:02<00:31,  3.61it/s, GPU RAM: 4.47 G/8.00 G]:   6%|█▌                        | 7/120 [00:02<00:31,  3.61it/s, GPU RAM: 4.47 G/8.00 G]:   7%|█▋                        | 8/120 [00:02<00:30,  3.67it/s, GPU RAM: 4.47 G/8.00 G]:   7%|█▋                        | 8/120 [00:02<00:30,  3.67it/s, GPU RAM: 4.47 G/8.00 G]:   8%|█▉                        | 9/120 [00:02<00:29,  3.72it/s, GPU RAM: 4.47 G/8.00 G]:   8%|█▉                        | 9/120 [00:02<00:29,  3.72it/s, GPU RAM: 4.47 G/8.00 G]:   8%|██                       | 10/120 [00:02<00:28,  3.81it/s, GPU RAM: 4.47 G/8.00 G]:   8%|██                       | 10/120 [00:03<00:28,  3.81it/s, GPU RAM: 4.47 G/8.00 G]:   9%|██▎                      | 11/120 [00:03<00:28,  3.78it/s, GPU RAM: 4.47 G/8.00 G]:   9%|██▎                      | 11/120 [00:03<00:28,  3.78it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▌                      | 12/120 [00:03<00:27,  3.86it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▌                      | 12/120 [00:03<00:27,  3.86it/s, GPU RAM: 4.47 G/8.00 G]:  11%|██▋                      | 13/120 [00:03<00:27,  3.95it/s, GPU RAM: 4.47 G/8.00 G]:  11%|██▋                      | 13/120 [00:03<00:27,  3.95it/s, GPU RAM: 4.47 G/8.00 G]:  12%|██▉                      | 14/120 [00:03<00:26,  4.03it/s, GPU RAM: 4.47 G/8.00 G]:  12%|██▉                      | 14/120 [00:04<00:26,  4.03it/s, GPU RAM: 4.47 G/8.00 G]:  12%|███▏                     | 15/120 [00:04<00:26,  3.99it/s, GPU RAM: 4.47 G/8.00 G]:  12%|███▏                     | 15/120 [00:04<00:26,  3.99it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▎                     | 16/120 [00:04<00:26,  3.95it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▎                     | 16/120 [00:04<00:26,  3.95it/s, GPU RAM: 4.47 G/8.00 G]:  14%|███▌                     | 17/120 [00:04<00:25,  3.99it/s, GPU RAM: 4.47 G/8.00 G]:  14%|███▌                     | 17/120 [00:04<00:25,  3.99it/s, GPU RAM: 4.47 G/8.00 G]:  15%|███▊                     | 18/120 [00:04<00:25,  4.00it/s, GPU RAM: 4.47 G/8.00 G]:  15%|███▊                     | 18/120 [00:05<00:25,  4.00it/s, GPU RAM: 4.47 G/8.00 G]:  16%|███▉                     | 19/120 [00:05<00:25,  3.91it/s, GPU RAM: 4.47 G/8.00 G]:  16%|███▉                     | 19/120 [00:05<00:25,  3.91it/s, GPU RAM: 4.47 G/8.00 G]:  17%|████▏                    | 20/120 [00:05<00:25,  3.98it/s, GPU RAM: 4.47 G/8.00 G]:  17%|████▏                    | 20/120 [00:05<00:25,  3.98it/s, GPU RAM: 4.47 G/8.00 G]:  18%|████▍                    | 21/120 [00:05<00:24,  3.98it/s, GPU RAM: 4.47 G/8.00 G]:  18%|████▍                    | 21/120 [00:05<00:24,  3.98it/s, GPU RAM: 4.47 G/8.00 G]:  18%|████▌                    | 22/120 [00:05<00:24,  4.02it/s, GPU RAM ...
# 27 Jan 19:56    INFO  epoch 0 training [time: 32.11s, train loss: 1171.6022]
# Evaluate   :   0%|                                                           | 0/61 [00:00<?, ?it/s]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 4.47 G/8.00 G]:   0%|                                   | 0/61 [00:00<?, ?it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▉                          | 2/61 [00:00<00:05, 11.54it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▉                          | 2/61 [00:00<00:05, 11.54it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▉                          | 2/61 [00:00<00:05, 11.54it/s, GPU RAM: 4.47 G/8.00 G]:   7%|█▊                         | 4/61 [00:00<00:04, 11.77it/s, GPU RAM: 4.47 G/8.00 G]:   7%|█▊                         | 4/61 [00:00<00:04, 11.77it/s, GPU RAM: 4.47 G/8.00 G]:   7%|█▊                         | 4/61 [00:00<00:04, 11.77it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:04, 11.89it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:04, 11.89it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▋                        | 6/61 [00:00<00:04, 11.89it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▌                       | 8/61 [00:00<00:04, 11.91it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▌                       | 8/61 [00:00<00:04, 11.91it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▌                       | 8/61 [00:00<00:04, 11.91it/s, GPU RAM: 4.47 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:04, 11.93it/s, GPU RAM: 4.47 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:04, 11.93it/s, GPU RAM: 4.47 G/8.00 G]:  16%|████▎                     | 10/61 [00:00<00:04, 11.93it/s, GPU RAM: 4.47 G/8.00 G]:  20%|█████                     | 12/61 [00:01<00:04, 11.79it/s, GPU RAM: 4.47 G/8.00 G]:  20%|█████                     | 12/61 [00:01<00:04, 11.79it/s, GPU RAM: 4.47 G/8.00 G]:  20%|█████                     | 12/61 [00:01<00:04, 11.79it/s, GPU RAM: 4.47 G/8.00 G]:  23%|█████▉                    | 14/61 [00:01<00:04, 11.60it/s, GPU RAM: 4.47 G/8.00 G]:  23%|█████▉                    | 14/61 [00:01<00:04, 11.60it/s, GPU RAM: 4.47 G/8.00 G]:  23%|█████▉                    | 14/61 [00:01<00:04, 11.60it/s, GPU RAM: 4.47 G/8.00 G]:  26%|██████▊                   | 16/61 [00:01<00:03, 11.65it/s, GPU RAM: 4.47 G/8.00 G]:  26%|██████▊                   | 16/61 [00:01<00:03, 11.65it/s, GPU RAM: 4.47 G/8.00 G]:  26%|██████▊                   | 16/61 [00:01<00:03, 11.65it/s, GPU RAM: 4.47 G/8.00 G]:  30%|███████▋                  | 18/61 [00:01<00:03, 11.45it/s, GPU RAM: 4.47 G/8.00 G]:  30%|███████▋                  | 18/61 [00:01<00:03, 11.45it/s, GPU RAM: 4.47 G/8.00 G]:  30%|███████▋                  | 18/61 [00:01<00:03, 11.45it/s, GPU RAM: 4.47 G/8.00 G]:  33%|████████▌                 | 20/61 [00:01<00:03, 11.59it/s, GPU RAM: 4.47 G/8.00 G]:  33%|████████▌                 | 20/61 [00:01<00:03, 11.59it/s, GPU RAM: 4.47 G/8.00 G]:  33%|████████▌                 | 20/61 [00:01<00:03, 11.59it/s, GPU RAM: 4.47 G/8.00 G]:  36%|█████████▍                | 22/61 [00:01<00:03, 11.74it/s, GPU RAM: 4.47 G/8.00 G]:  36%|█████████▍                | 22/61 [00:01<00:03, 11.74it/s, GPU RAM: 4.47 G/8.00 G]:  36%|█████████▍                | 22/61 [00:02<00:03, 11.74it/s, GPU RAM: 4.47 G/8.00 G]:  39%|██████████▏               | 24/61 [00:02<00:03, 11.48it/s, GPU RAM: 4.47 G/8.00 G]:  39%|██████████▏               | 24/61 [00:02<00:03, 11.48it/s, GPU RAM: 4.47 G/8.00 G]:  39%|██████████▏               | 24/61 [00:02<00:03, 11.48it/s, GPU RAM: 4.47 G/8.00 G]:  43%|███████████               | 26/61 [00:02<00:04,  7.60it/s, GPU RAM: 4.47 G/8.00 G]:  43%|███████████               | 26/61 [00:02<00:04,  7.60it/s, GPU RAM: 4.47 G/8.00 G]:  43%|███████████               | 26/61 [00:02<00:04,  7.60it/s, GPU RAM: 4.47 G/8.00 G]:  46%|███████████▉              | 28/61 [00:02<00:03,  8.49it/s, GPU RAM: 4.47 G/8.00 G]:  46%|███████████▉              | 28/61 [00:02<00:03,  8.49it/s, GPU RAM: 4.47 G/8.00 G]:  46%|███████████▉              | 28/61 [00:02<00:03,  8.49it/s, GPU RAM ...
# 27 Jan 20:01    INFO  epoch 0 evaluating [time: 307.06s, valid_score: 0.002400]
# 27 Jan 20:01    INFO  valid result:
# recall@1 : 0.001    recall@10 : 0.0085    recall@50 : 0.0326    recall@100 : 0.0526    mrr@1 : 0.001    mrr@10 : 0.0024    mrr@50 : 0.0035    mrr@100 : 0.0038    ndcg@1 : 0.001    ndcg@10 : 0.0038    ndcg@50 : 0.009    ndcg@100 : 0.0122    hit@1 : 0.001    hit@10 : 0.0085    hit@50 : 0.0326    hit@100 : 0.0526    precision@1 : 0.001    precision@10 : 0.0009    precision@50 : 0.0007    precision@100 : 0.0005    averagepopularity@1 : 872.0474    averagepopularity@10 : 503.147    averagepopularity@50 : 341.169    averagepopularity@100 : 279.0635    tailpercentage@1 : 0.0    tailpercentage@10 : 0.0    tailpercentage@50 : 0.0    tailpercentage@100 : 0.0    itemcoverage@1 : 0.0    itemcoverage@10 : 0.0005    itemcoverage@50 : 0.002    itemcoverage@100 : 0.0036
# 27 Jan 20:01    INFO  Saving current: saved\BERT4Rec-Jan-27-2024_19-56-03.pth
# 27 Jan 20:01    INFO  Loading model structure and parameters from saved\BERT4Rec-Jan-27-2024_19-56-03.pth
# Evaluate   :   0%|                                                          | 0/158 [00:00<?, ?it/s]:   0%|                                  | 0/158 [00:00<?, ?it/s, GPU RAM: 4.47 G/8.00 G]:   1%|▏                         | 1/158 [00:00<01:01,  2.57it/s, GPU RAM: 4.47 G/8.00 G]:   1%|▏                         | 1/158 [00:00<01:01,  2.57it/s, GPU RAM: 4.47 G/8.00 G]:   1%|▏                         | 1/158 [00:00<01:01,  2.57it/s, GPU RAM: 4.47 G/8.00 G]:   2%|▍                         | 3/158 [00:00<00:24,  6.32it/s, GPU RAM: 4.47 G/8.00 G]:   2%|▍                         | 3/158 [00:00<00:24,  6.32it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:21,  7.18it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:21,  7.18it/s, GPU RAM: 4.47 G/8.00 G]:   3%|▋                         | 4/158 [00:00<00:21,  7.18it/s, GPU RAM: 4.47 G/8.00 G]:   4%|▉                         | 6/158 [00:00<00:17,  8.90it/s, GPU RAM: 4.47 G/8.00 G]:   4%|▉                         | 6/158 [00:00<00:17,  8.90it/s, GPU RAM: 4.47 G/8.00 G]:   4%|▉                         | 6/158 [00:00<00:17,  8.90it/s, GPU RAM: 4.47 G/8.00 G]:   5%|█▎                        | 8/158 [00:00<00:15,  9.73it/s, GPU RAM: 4.47 G/8.00 G]:   5%|█▎                        | 8/158 [00:01<00:15,  9.73it/s, GPU RAM: 4.47 G/8.00 G]:   5%|█▎                        | 8/158 [00:01<00:15,  9.73it/s, GPU RAM: 4.47 G/8.00 G]:   6%|█▌                       | 10/158 [00:01<00:14, 10.34it/s, GPU RAM: 4.47 G/8.00 G]:   6%|█▌                       | 10/158 [00:01<00:14, 10.34it/s, GPU RAM: 4.47 G/8.00 G]:   6%|█▌                       | 10/158 [00:01<00:14, 10.34it/s, GPU RAM: 4.47 G/8.00 G]:   8%|█▉                       | 12/158 [00:01<00:13, 10.89it/s, GPU RAM: 4.47 G/8.00 G]:   8%|█▉                       | 12/158 [00:01<00:13, 10.89it/s, GPU RAM: 4.47 G/8.00 G]:   8%|█▉                       | 12/158 [00:01<00:13, 10.89it/s, GPU RAM: 4.47 G/8.00 G]:   9%|██▏                      | 14/158 [00:01<00:12, 11.32it/s, GPU RAM: 4.47 G/8.00 G]:   9%|██▏                      | 14/158 [00:01<00:12, 11.32it/s, GPU RAM: 4.47 G/8.00 G]:   9%|██▏                      | 14/158 [00:01<00:12, 11.32it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▌                      | 16/158 [00:01<00:12, 11.30it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▌                      | 16/158 [00:01<00:12, 11.30it/s, GPU RAM: 4.47 G/8.00 G]:  10%|██▌                      | 16/158 [00:01<00:12, 11.30it/s, GPU RAM: 4.47 G/8.00 G]:  11%|██▊                      | 18/158 [00:01<00:12, 11.07it/s, GPU RAM: 4.47 G/8.00 G]:  11%|██▊                      | 18/158 [00:01<00:12, 11.07it/s, GPU RAM: 4.47 G/8.00 G]:  11%|██▊                      | 18/158 [00:01<00:12, 11.07it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▏                     | 20/158 [00:02<00:12, 11.29it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▏                     | 20/158 [00:02<00:12, 11.29it/s, GPU RAM: 4.47 G/8.00 G]:  13%|███▏                     | 20/158 [00:02<00:12, 11.29it/s, GPU RAM: 4.47 G/8.00 G]:  14%|███▍                     | 22/158 [00:02<00:12, 11.14it/s, GPU RAM: 4.47 G/8.00 G]:  14%|███▍                     | 22/158 [00:02<00:12, 11.14it/s, GPU RAM: 4.47 G/8.00 G]:  14%|███▍                     | 22/158 [00:02<00:12, 11.14it/s, GPU RAM: 4.47 G/8.00 G]:  15%|███▊                     | 24/158 [00:02<00:11, 11.36it/s, GPU RAM: 4.47 G/8.00 G]:  15%|███▊                     | 24/158 [00:02<00:11, 11.36it/s, GPU RAM: 4.47 G/8.00 G]:  15%|███▊                     | 24/158 [00:02<00:11, 11.36it/s, GPU RAM: 4.47 G/8.00 G]:  16%|████                     | 26/158 [00:02<00:11, 11.21it/s, GPU RAM: 4.47 G/8.00 G]:  16%|████                     | 26/158 [00:02<00:11, 11.21it/s, GPU RAM: 4.47 G/8.00 G]:  16%|████                     | 26/158 [00:02<00:11, 11.21it/s, GPU RAM: 4.47 G/8.00 G]:  18%|████▍                    | 28/158 [00:02<00:11, 11.44it/s, GPU RAM: 4.47 G/8.00 G]:  18%|████▍                    | 28/158 [00:02<00:11, 11.44it/s, GPU RAM ...
# 27 Jan 20:18    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     0.70 %     |
# +-------------+----------------+
# | GPU         | 4.48 G/8.00 G  |
# +-------------+----------------+
# | Memory      | 0.66 G/15.21 G |
# +-------------+----------------+
# 27 Jan 20:18    INFO  best valid : OrderedDict([('recall@1', 0.001), ('recall@10', 0.0085), ('recall@50', 0.0326), ('recall@100', 0.0526), ('mrr@1', 0.001), ('mrr@10', 0.0024), ('mrr@50', 0.0035), ('mrr@100', 0.0038), ('ndcg@1', 0.001), ('ndcg@10', 0.0038), ('ndcg@50', 0.009), ('ndcg@100', 0.0122), ('hit@1', 0.001), ('hit@10', 0.0085), ('hit@50', 0.0326), ('hit@100', 0.0526), ('precision@1', 0.001), ('precision@10', 0.0009), ('precision@50', 0.0007), ('precision@100', 0.0005), ('averagepopularity@1', 872.0474), ('averagepopularity@10', 503.147), ('averagepopularity@50', 341.169), ('averagepopularity@100', 279.0635), ('tailpercentage@1', 0.0), ('tailpercentage@10', 0.0), ('tailpercentage@50', 0.0), ('tailpercentage@100', 0.0), ('itemcoverage@1', 0.0), ('itemcoverage@10', 0.0005), ('itemcoverage@50', 0.002), ('itemcoverage@100', 0.0036)])
# 27 Jan 20:18    INFO  test result: OrderedDict([('recall@1', 0.0004), ('recall@10', 0.0037), ('recall@50', 0.0175), ('recall@100', 0.0275), ('mrr@1', 0.0004), ('mrr@10', 0.001), ('mrr@50', 0.0016), ('mrr@100', 0.0018), ('ndcg@1', 0.0004), ('ndcg@10', 0.0016), ('ndcg@50', 0.0046), ('ndcg@100', 0.0063), ('hit@1', 0.0004), ('hit@10', 0.0037), ('hit@50', 0.0175), ('hit@100', 0.0275), ('precision@1', 0.0004), ('precision@10', 0.0004), ('precision@50', 0.0003), ('precision@100', 0.0003), ('averagepopularity@1', 887.8212), ('averagepopularity@10', 508.9741), ('averagepopularity@50', 344.4864), ('averagepopularity@100', 280.6821), ('tailpercentage@1', 0.0), ('tailpercentage@10', 0.0), ('tailpercentage@50', 0.0), ('tailpercentage@100', 0.0), ('itemcoverage@1', 0.0), ('itemcoverage@10', 0.0005), ('itemcoverage@50', 0.002), ('itemcoverage@100', 0.0036)])

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/BERT4Rec_test.json", indent=2)

# %% [markdown]
# # Caser

# %%
dict_results = run_recbole(model="Caser", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/Caser_test.json", indent=2)

# %% [markdown]
# # TransRec

# %%
dict_results = run_recbole(model="TransRec", config_file_list=['config.yaml'],  dataset='RECEIPT_LINES')

# %%
import os
import pandas as pd

if not os.path.exists("./results"):
    os.mkdir("./results")
pd.Series(dict(dict_results['test_result'])).to_json("./results/TransRec_test.json", indent=2)
